# %% [markdown]
# Vishnunarayan Nagpal TE COMP 3 - 22

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Imports Pandas for data manipulation and NumPy for numerical operations.

# %%
df = pd.read_csv('iris.csv')
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Loads the Iris dataset into a DataFrame and displays statistical summary of numerical columns.

# %%
df.isnull()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %% [markdown]
# quickly view the beginning and end of the dataset.

# %%
print("First 5 values:\n", df.head())
print("Last 5 values:\n", df.tail())
# Out:
# First 5 values:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# Last 5 values:
#       sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %% [markdown]
# Identifies duplicate rows in the dataset.

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %% [markdown]
# Checks whether any missing (NULL) values are present.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Provides a summary of the dataset structure.

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# Shows number of rows and columns in the dataset.

# %%
df["sepal.length"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: sepal.length, Length: 150, dtype: bool

# %% [markdown]
# Checks missing values in a specific column.

# %%
y = df.drop(["petal.length"], axis=1)
print(y)
# Out:
#      sepal.length  sepal.width  petal.width    variety
# 0             5.1          3.5          0.2     Setosa
# 1             4.9          3.0          0.2     Setosa
# 2             4.7          3.2          0.2     Setosa
# 3             4.6          3.1          0.2     Setosa
# 4             5.0          3.6          0.2     Setosa
# ..            ...          ...          ...        ...
# 145           6.7          3.0          2.3  Virginica
# 146           6.3          2.5          1.9  Virginica
# 147           6.5          3.0          2.0  Virginica
# 148           6.2          3.4          2.3  Virginica
# 149           5.9          3.0          1.8  Virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# Removes an unwanted column from the dataset.

# %%
df['variety'].replace(['Setosa', 'Virginica'], [0, 1], inplace=True)
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width variety
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       1
# 146           6.3          2.5           5.0          1.9       1
# 147           6.5          3.0           5.2          2.0       1
# 148           6.2          3.4           5.4          2.3       1
# 149           5.9          3.0           5.1          1.8       1
#
# [150 rows x 5 columns]
# ...

# %% [markdown]
# Converts categorical data into numerical form for analysis.

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %% [markdown]
# Displays number of missing values in each column.
